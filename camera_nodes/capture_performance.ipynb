# %%
import pandas as pd

# %%
df = pd.read_csv("captures/timing.csv")

# %%
df.tail(20)

# %%
print(df.tail(20))

# %%
df.describe([.1, .5, .9, .95, .99]).T

# %%
print(df.describe([.1, .5, .9, .95, .99]).T)

# %%
import os

# %%
os.listdir()

# %%
def print_file(filename):
    with open(filename) as fo:
        print(fo.read())
    print("\n==================================\n")

files = [
    'main.py',
    'threading_utils.py',
    'scheduler.py',
    'camera.py',
    'processing.py',
]

print("Here is my code:\n")

for file in files:
    print_file(file)

print("Here is a dataframe of the timing file:\n")
print(df.tail(20))

print("And some summary stats:\n")
print(df.describe([.1, .5, .9, .95, .99]).T)
